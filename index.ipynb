# %% [raw]
# ---
# title: "Blog"
# page-layout: full
# ---

# %% [markdown]
# ## 📰 Últimos Posts
#
# ```{listing}
# contents: .
# type: default
# sort: "date desc"
# fields: [title, date, categories]
# image: false
