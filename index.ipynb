# %% [raw]
# ---
# title: "Boris DevOps Lab – Blog"
# page-layout: full
# listing:
#   contents: posts
#   type: default
#   sort: "date desc"
#   categories: true
#   image-placeholder: ""
#   fields: [image, title, description, date, categories]
# ---

# %% [markdown]
# # 🧠 Boris DevOps Blog
# ### Automatizado con AWS + Bedrock + GitHub Actions 🚀
#
# Bienvenido a mi blog técnico generado automáticamente mediante IA y desplegado mediante CI/CD.
#
# Aquí publico contenido sobre:
#
# - AWS Lambda
# - Amazon Bedrock
# - APIs Serverless
# - Observabilidad
# - Automatización inteligente
# - DevOps + Infra as Code

# %% [markdown]
# ---
#
# ## 📰 Últimos Posts
#
# ::: {.blog-grid}
#
# ```{listing}
# contents: posts
# type: grid
# sort: "date desc"
# limit: 12
# grid-columns: 3
# image-placeholder: ""
# fields: [image, title, description, date, categories]
# card-style: "border-radius: 12px; padding: 0; overflow: hidden;"
